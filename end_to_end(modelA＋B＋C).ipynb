# %% [markdown]
# <a href="https://colab.research.google.com/github/skywalker0803r/works/blob/master/end_to_end(modelA%EF%BC%8BB%EF%BC%8BC).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import joblib
from torch import nn
from tqdm import tqdm_notebook as tqdm
#!pip install autorch
import autorch

# %%
c = joblib.load('/content/drive/MyDrive/台塑輕油案子/data/phase2/dataset/col_names.pkl')
c.keys()
# Out:
# dict_keys(['xna', 'xle', 'xhc', 'xhe', 'fna', 'fle', 'fhc', 'fhe', 'yld', 'Tray_temp', 'duty', 'Rate_m3', 'Rate_ton', 'sle', 'shc', 'she', 'case'])

# %%
df = pd.read_csv('/content/drive/MyDrive/台塑輕油案子/data/phase2/dataset/train.csv',index_col=0)
df = df.dropna(axis=0).astype('float32')
df.head(3)
# Out:
#         Naphtha Properties_Oxygen_wt%  ...  Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr
# 001-01                            0.0  ...                                              100.0
# 001-02                            0.0  ...                                              100.0
# 001-03                            0.0  ...                                              100.0
#
# [3 rows x 404 columns]

# %%
# X
X = df[c['case']+c['xna']]
print('X.shape',X.shape)

# modelA的Y
Y1 = df[c['sle']+c['shc']+c['she']]
print('Y1.shape',Y1.shape)

duty = df[c['duty']]
density = pd.DataFrame(df[c['Rate_ton']].values/df[c['Rate_m3']].values,
                       columns=['NA_density','LE_density','HC_density','HE_density'],
                       index=df.index)
# modelB的Y
Y2 = duty.join(density)
print('Y2.shape',Y2.shape)

# modelC的Y
Y3 = df[c['Tray_temp']+c['fna']+c['yld']]
print('Y3.shape',Y3.shape)

# (modelA + modelB + modelC)的Y
Y = Y1.join(Y2).join(Y3)
print('Y.shape',Y.shape)
# Out:
# X.shape (16498, 58)
# Y1.shape (16498, 162)
# Y2.shape (16498, 7)
# Y3.shape (16498, 8)
# Y.shape (16498, 177)

# %%
wt = df[c['xle']+c['xhc']+c['xhe']]
df = X.join(Y).join(wt)
x_col = X.columns.tolist()
y_col = Y.columns.tolist()

# %%
normalize_idx_list = []
for i in range(54):
  normalize_idx_list.append([y_col.index(c['sle'][i]),
                             y_col.index(c['shc'][i]),
                             y_col.index(c['she'][i])])
for idx in tqdm(normalize_idx_list):
  assert np.allclose(df[y_col].iloc[:,idx].sum(axis=1),1) # 因為分離係數要確保質量平衡
# Out:
# HBox(children=(FloatProgress(value=0.0, max=54.0), HTML(value='')))

# %%
model = autorch.utils.PartBulider(df,x_col,y_col,normalize_idx_list=normalize_idx_list,device='cuda:0') # 使用 gpu train 快一些
model.loss_fn = nn.SmoothL1Loss() # SmoothL1增加穩健性
model.train()
# Out:
#   0%|          | 1/300 [00:00<03:56,  1.26it/s]
# epoch:0 train_loss:0.0067 valid_loss:0.0017
#  17%|█▋        | 51/300 [00:39<03:13,  1.29it/s]
# epoch:50 train_loss:0.0002 valid_loss:0.0002
#  34%|███▎      | 101/300 [01:18<02:35,  1.28it/s]
# epoch:100 train_loss:0.0001 valid_loss:0.0002
#  50%|█████     | 151/300 [01:57<01:55,  1.29it/s]
# epoch:150 train_loss:0.0001 valid_loss:0.0001
#  67%|██████▋   | 201/300 [02:36<01:15,  1.31it/s]
# epoch:200 train_loss:0.0001 valid_loss:0.0001
#  84%|████████▎ | 251/300 [03:15<00:37,  1.30it/s]
# epoch:250 train_loss:0.0000 valid_loss:0.0001
# 100%|██████████| 300/300 [03:53<00:00,  1.28it/s]
# Sequential(
#   (0): Linear(in_features=58, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=256, out_features=177, bias=True)
#   (5): Sigmoid()
# )

# %%
res = model.test()
res['MAPE'].replace([np.nan,np.inf],0,inplace=True) # 當分母為'0'則mape會出現inf(若分子也為0得NaN),所以可以忽略NaN和inf
res
# Out:
#                                                           R2  ...      MAPE
# Individual Component to Light End Split Factor_...         0  ...  0.012494
# Individual Component to Light End Split Factor_...         0  ...  0.012579
# Individual Component to Light End Split Factor_...         0  ...  0.011455
# Individual Component to Light End Split Factor_...  0.985228  ...  0.028901
# Individual Component to Light End Split Factor_...  0.984053  ...  0.067640
# ...                                                      ...  ...       ...
# Yield Summary_Reflux Rate_m3/hr                     0.986512  ...  1.669383
# Yield Summary_Light End Prod. Rate_m3/hr            0.997153  ...  3.378990
# Yield Summary_Heart Cut Prod. Rate_m3/hr            0.996606  ...  0.205767
# Yield Summary_Heavy End Prod. Rate_m3/hr            0.939275  ...  2.277090
# AVG                                                 0.889344  ...  0.000000
#
# [178 rows x 3 columns]

# %% [markdown]
# # 分離係數 to 重量百分比 (sp2wt)

# %%
from autorch.function import sp2wt
x_test = model.data['X_test']
y_pred = model.predict(x_test)
xna = x_test[c['xna']]
xle = sp2wt(xna.values,y_pred[c['sle']].values)
xhc = sp2wt(xna.values,y_pred[c['shc']].values)
xhe = sp2wt(xna.values,y_pred[c['she']].values)
wt_pred = np.hstack((xle,xhc,xhe))
wt_pred = pd.DataFrame(wt_pred,index=x_test.index,columns=c['xle']+c['xhc']+c['xhe'])
wt_pred = wt_pred.round(8)#四捨五入到小數點第8位
wt_pred.head()
# Out:
#         Light End Product Properties_Oxygen_wt%  ...  Heavy End Product Properties_n-Tridecane_wt%
# 332-02                                      0.0  ...                                           0.0
# 124-25                                      0.0  ...                                           0.0
# 125-14                                      0.0  ...                                           0.0
# 412-25                                      0.0  ...                                           0.0
# 024-28                                      0.0  ...                                           0.0
#
# [5 rows x 162 columns]

# %%
wt_real = df.loc[x_test.index,c['xle']+c['xhc']+c['xhe']]
wt_real.head()
# Out:
#         Light End Product Properties_Oxygen_wt%  ...  Heavy End Product Properties_n-Tridecane_wt%
# 332-02                                      0.0  ...                                           0.0
# 124-25                                      0.0  ...                                           0.0
# 125-14                                      0.0  ...                                           0.0
# 412-25                                      0.0  ...                                           0.0
# 024-28                                      0.0  ...                                           0.0
#
# [5 rows x 162 columns]

# %%
pd.set_option('display.max_rows',200)
res = model.show_metrics(wt_real,wt_pred)
res['MAPE'].replace([np.nan,np.inf],0,inplace=True)# 當分母為'0'則mape會出現inf(若分子也為0得NaN),所以可以忽略NaN和inf
res
# Out:
#                                                            R2  ...         MAPE
# Light End Product Properties_Oxygen_wt%                     1  ...     0.000000
# Light End Product Properties_Methane_wt%                    1  ...     0.000000
# Light End Product Properties_Ethane_wt%                     1  ...     0.000000
# Light End Product Properties_Propane_wt%             0.991965  ...     0.000000
# Light End Product Properties_n-Butane_wt%            0.995793  ...     0.000000
# Light End Product Properties_i-Pentane_wt%           0.995825  ...     0.889609
# Light End Product Properties_n-Pentane_wt%           0.998516  ...     0.883725
# Light End Product Properties_tr2-Pentene_wt%         0.993697  ...     0.000000
# Light End Product Properties_Cyclopentane_wt%        0.999312  ...     0.000000
# Light End Product Properties_3-Methylpentane_wt%     0.998818  ...     0.847976
# Light End Product Properties_tr2-Hexene_wt%          0.999453  ...     0.000000
# Light End Product Properties_n-Hexane_wt%            0.998634  ...     0.824641
# Light End Product Properties_Methylcyclopentane...    0.99468  ...     0.588468
# Light End Product Properties_2,2-Dimethylpentan...   0.986716  ...     1.695901
# Light End Product Properties_Benzene_wt%             0.998848  ...     0.000000
# Light End Product Properties_Cyclohexane_wt%          0.98985  ...     2.617723
# Light End Product Properties_2,2,3-Trimethylbut...   0.992255  ...     2.739520
# Light End Product Properties_4-Methyl-1-hexene_wt%   0.996312  ...     8.020231
# Light End Product Properties_2-Methylhexane_wt%      0.996776  ...     8.605548
# Light End Product Properties_t-1,3-Dimethylcycl...   0.997554  ...    15.007734
# Light End Product Properties_n-Heptane_wt%           0.988983  ...    22.971869
# Light End Product Properties_H2O_wt%                        1  ...     0.000000
# Light End Product Properties_Methylcyclohexane_wt%   0.992891  ...    32.865098
# Light End Product Properties_Ethylcyclopentane_wt%   0.993038  ...    42.422327
# Light End Product Properties_2,3-Dimethyl-1-hex...   0.984142  ...     0.000000
# Light End Product Properties_Toluene_wt%             0.989295  ...    38.851115
# Light End Product Properties_2-Methylheptane_wt%     0.979339  ...    82.136011
# Light End Product Properties_n-Octane_wt%            0.977524  ...     0.000000
# Light End Product Properties_Ethylcyclohexane_wt%    0.979288  ...     0.000000
# Light End Product Properties_EthylBenzene_wt%        0.952526  ...     0.000000
# Light End Product Properties_P-Xylene_wt%            0.661575  ...     0.000000
# Light End Product Properties_M-Xylene_wt%             0.82649  ...     0.000000
# Light End Product Properties_O-Xylene_wt%                   0  ...     0.000000
# Light End Product Properties_2-Methyloctane_wt%      0.689534  ...     0.000000
# Light End Product Properties_1-Nonene_wt%                   0  ...     0.000000
# Light End Product Properties_n-Nonane_wt%                   0  ...     0.000000
# Light End Product Properties_i-Propylbenzene_wt%            0  ...     0.000000
# Light End Product Properties_1-trans-3,5-Trimet...   0.732043  ...     0.000000
# Light End Product Properties_n-Propylcyclohexan...          0  ...     0.000000
# Light End Product Properties_n-Propylbenzene_wt%            0  ...     0.000000
# Light End Product Properties_1,3,5-Trimethylben...          0  ...     0.000000
# Light End Product Properties_1-Methyl-2-ethylbe...          0  ...     0.000000
# Light End Product Properties_1,2,3-Trimethylben...          0  ...     0.000000
# Light End Product Properties_2,4-Dimethyloctane...          0  ...     0.000000
# Light End Product Properties_2,2,3,3-Tetramethy...          0  ...     0.000000
# Light End Product Properties_3-Methylnonane_wt%             0  ...     0.000000
# Light End Product Properties_tert-Butylcyclohex...          0  ...     0.000000
# Light End Product Properties_n-Decane_wt%           -0.762842  ...     0.000000
# Light End Product Properties_1,2-Diethylbenzene...          0  ...     0.000000
# Light End Product Properties_n-Undecane_wt%         -0.896123  ...     0.000000
# Light End Product Properties_n-Pentylbenzene_wt%     -0.13633  ...   100.000000
# Light End Product Properties_n-Dodecane_wt%         -0.106737  ...     0.000000
# Light End Product Properties_n-Hexylbenzene_wt%    -0.0131692  ...     0.000000
# Light End Product Properties_n-Tridecane_wt%                1  ...     0.000000
# Heart Cut Product Properties_Oxygen_wt%                     1  ...     0.000000
# Heart Cut Product Properties_Methane_wt%                    1  ...     0.000000
# Heart Cut Product Properties_Ethane_wt%                     1  ...     0.000000
# Heart Cut Product Properties_Propane_wt%             0.998097  ...     0.000000
# Heart Cut Product Properties_n-Butane_wt%            0.997632  ...     0.000000
# Heart Cut Product Properties_i-Pentane_wt%           0.998462  ...     2.406479
# Heart Cut Product Properties_n-Pentane_wt%           0.998343  ...     2.460650
# Heart Cut Product Properties_tr2-Pentene_wt%         0.998405  ...     0.000000
# Heart Cut Product Properties_Cyclopentane_wt%        0.985447  ...     0.000000
# Heart Cut Product Properties_3-Methylpentane_wt%     0.995856  ...     2.668555
# Heart Cut Product Properties_tr2-Hexene_wt%          0.998287  ...     0.000000
# Heart Cut Product Properties_n-Hexane_wt%            0.996319  ...     2.529936
# Heart Cut Product Properties_Methylcyclopentane...   0.997696  ...     1.351326
# Heart Cut Product Properties_2,2-Dimethylpentan...   0.999282  ...     0.672767
# Heart Cut Product Properties_Benzene_wt%             0.999432  ...     0.000000
# Heart Cut Product Properties_Cyclohexane_wt%         0.999358  ...     0.785846
# Heart Cut Product Properties_2,2,3-Trimethylbut...   0.999531  ...     0.512288
# Heart Cut Product Properties_4-Methyl-1-hexene_wt%   0.999734  ...     0.323158
# Heart Cut Product Properties_2-Methylhexane_wt%      0.999853  ...     0.215228
# Heart Cut Product Properties_t-1,3-Dimethylcycl...   0.999945  ...     0.177647
# Heart Cut Product Properties_n-Heptane_wt%           0.999924  ...     0.158760
# Heart Cut Product Properties_H2O_wt%                        1  ...     0.000000
# Heart Cut Product Properties_Methylcyclohexane_wt%   0.999949  ...     0.158261
# Heart Cut Product Properties_Ethylcyclopentane_wt%   0.999949  ...     0.158501
# Heart Cut Product Properties_2,3-Dimethyl-1-hex...   0.999898  ...     0.162434
# Heart Cut Product Properties_Toluene_wt%             0.999871  ...     0.159927
# Heart Cut Product Properties_2-Methylheptane_wt%     0.999762  ...     0.181978
# Heart Cut Product Properties_n-Octane_wt%            0.999469  ...     0.260800
# Heart Cut Product Properties_Ethylcyclohexane_wt%    0.999583  ...     0.306346
# Heart Cut Product Properties_EthylBenzene_wt%        0.999918  ...     0.326965
# Heart Cut Product Properties_P-Xylene_wt%            0.999865  ...     0.416731
# Heart Cut Product Properties_M-Xylene_wt%            0.999842  ...     0.447696
# Heart Cut Product Properties_O-Xylene_wt%            0.999661  ...     0.636397
# Heart Cut Product Properties_2-Methyloctane_wt%      0.998868  ...     0.616588
# Heart Cut Product Properties_1-Nonene_wt%            0.998718  ...     0.623207
# Heart Cut Product Properties_n-Nonane_wt%             0.99904  ...     0.527545
# Heart Cut Product Properties_i-Propylbenzene_wt%     0.999278  ...     0.548130
# Heart Cut Product Properties_1-trans-3,5-Trimet...   0.998751  ...     0.571143
# Heart Cut Product Properties_n-Propylcyclohexan...   0.997522  ...     0.496049
# Heart Cut Product Properties_n-Propylbenzene_wt%     0.998621  ...     0.511682
# Heart Cut Product Properties_1,3,5-Trimethylben...   0.998804  ...     0.515798
# Heart Cut Product Properties_1-Methyl-2-ethylbe...   0.998713  ...     0.501449
# Heart Cut Product Properties_1,2,3-Trimethylben...   0.999762  ...     0.486688
# Heart Cut Product Properties_2,4-Dimethyloctane...   0.997607  ...     0.593515
# Heart Cut Product Properties_2,2,3,3-Tetramethy...   0.998414  ...     0.496524
# Heart Cut Product Properties_3-Methylnonane_wt%      0.999286  ...     0.500268
# Heart Cut Product Properties_tert-Butylcyclohex...   0.999681  ...     0.466749
# Heart Cut Product Properties_n-Decane_wt%            0.999716  ...     0.000000
# Heart Cut Product Properties_1,2-Diethylbenzene...   0.999744  ...     0.502199
# Heart Cut Product Properties_n-Undecane_wt%          0.999797  ...     0.000000
# Heart Cut Product Properties_n-Pentylbenzene_wt%     0.999705  ...     0.558795
# Heart Cut Product Properties_n-Dodecane_wt%          0.999911  ...     0.000000
# Heart Cut Product Properties_n-Hexylbenzene_wt%      0.999687  ...     0.000000
# Heart Cut Product Properties_n-Tridecane_wt%                1  ...     0.000000
# Heavy End Product Properties_Oxygen_wt%                     1  ...     0.000000
# Heavy End Product Properties_Methane_wt%                    1  ...     0.000000
# Heavy End Product Properties_Ethane_wt%                     1  ...     0.000000
# Heavy End Product Properties_Propane_wt%                    1  ...     0.000000
# Heavy End Product Properties_n-Butane_wt%                   0  ...     0.000000
# Heavy End Product Properties_i-Pentane_wt%                  0  ...     0.000000
# Heavy End Product Properties_n-Pentane_wt%                  0  ...     0.000000
# Heavy End Product Properties_tr2-Pentene_wt%                0  ...     0.000000
# Heavy End Product Properties_Cyclopentane_wt%               0  ...     0.000000
# Heavy End Product Properties_3-Methylpentane_wt%            0  ...     0.000000
# Heavy End Product Properties_tr2-Hexene_wt%                 0  ...     0.000000
# Heavy End Product Properties_n-Hexane_wt%            0.892208  ...     0.000000
# Heavy End Product Properties_Methylcyclopentane...   0.994527  ...     0.000000
# Heavy End Product Properties_2,2-Dimethylpentan...   0.989578  ...     0.000000
# Heavy End Product Properties_Benzene_wt%             0.998123  ...     0.000000
# Heavy End Product Properties_Cyclohexane_wt%         0.995605  ...     0.000000
# Heavy End Product Properties_2,2,3-Trimethylbut...   0.994055  ...     0.000000
# Heavy End Product Properties_4-Methyl-1-hexene_wt%   0.990778  ...     0.000000
# Heavy End Product Properties_2-Methylhexane_wt%       0.99017  ...     0.000000
# Heavy End Product Properties_t-1,3-Dimethylcycl...   0.990005  ...     0.000000
# Heavy End Product Properties_n-Heptane_wt%            0.98857  ...     0.000000
# Heavy End Product Properties_H2O_wt%                        1  ...     0.000000
# Heavy End Product Properties_Methylcyclohexane_wt%    0.99151  ...     0.000000
# Heavy End Product Properties_Ethylcyclopentane_wt%    0.99005  ...     0.000000
# Heavy End Product Properties_2,3-Dimethyl-1-hex...   0.959289  ...     0.000000
# Heavy End Product Properties_Toluene_wt%             0.980316  ...     0.000000
# Heavy End Product Properties_2-Methylheptane_wt%     0.879073  ...  1596.870232
# Heavy End Product Properties_n-Octane_wt%            0.836655  ...  3149.184227
# Heavy End Product Properties_Ethylcyclohexane_wt%     0.98669  ...    39.062265
# Heavy End Product Properties_EthylBenzene_wt%        0.987112  ...    70.940804
# Heavy End Product Properties_P-Xylene_wt%            0.989766  ...   110.617316
# Heavy End Product Properties_M-Xylene_wt%            0.990003  ...   120.059073
# Heavy End Product Properties_O-Xylene_wt%            0.991922  ...   199.003112
# Heavy End Product Properties_2-Methyloctane_wt%      0.991028  ...   139.742517
# Heavy End Product Properties_1-Nonene_wt%            0.989326  ...   200.334573
# Heavy End Product Properties_n-Nonane_wt%            0.991907  ...   222.229481
# Heavy End Product Properties_i-Propylbenzene_wt%     0.983133  ...   175.568080
# Heavy End Product Properties_1-trans-3,5-Trimet...    0.99233  ...   119.942820
# Heavy End Product Properties_n-Propylcyclohexan...   0.988315  ...     3.741464
# Heavy End Product Properties_n-Propylbenzene_wt%     0.986277  ...     4.069567
# Heavy End Product Properties_1,3,5-Trimethylben...   0.992365  ...     1.722777
# Heavy End Product Properties_1-Methyl-2-ethylbe...   0.986332  ...     4.109626
# Heavy End Product Properties_1,2,3-Trimethylben...   0.993021  ...     1.665678
# Heavy End Product Properties_2,4-Dimethyloctane...   0.976498  ...    52.575815
# Heavy End Product Properties_2,2,3,3-Tetramethy...   0.991834  ...     1.916085
# Heavy End Product Properties_3-Methylnonane_wt%      0.995252  ...     1.633660
# Heavy End Product Properties_tert-Butylcyclohex...   0.996464  ...     1.678657
# Heavy End Product Properties_n-Decane_wt%            0.986057  ...     0.000000
# Heavy End Product Properties_1,2-Diethylbenzene...   0.991293  ...     1.716001
# Heavy End Product Properties_n-Undecane_wt%            0.9798  ...     0.000000
# Heavy End Product Properties_n-Pentylbenzene_wt%     0.990031  ...     1.751503
# Heavy End Product Properties_n-Dodecane_wt%          0.993015  ...     0.000000
# Heavy End Product Properties_n-Hexylbenzene_wt%      0.989762  ...     0.000000
# Heavy End Product Properties_n-Tridecane_wt%                1  ...     0.000000
# AVG                                                   0.81412  ...     0.000000
#
# [163 rows x 3 columns]
