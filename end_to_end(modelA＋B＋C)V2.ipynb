# %% [markdown]
# <a href="https://colab.research.google.com/github/skywalker0803r/works/blob/master/end_to_end(modelA%EF%BC%8BB%EF%BC%8BC)V2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import joblib
from torch import nn
from tqdm import tqdm_notebook as tqdm
#!pip install autorch
import autorch

# %%
c = joblib.load('/content/drive/MyDrive/台塑輕油案子/data/phase2/dataset/col_names.pkl')
c.keys()
# Out:
# dict_keys(['xna', 'xle', 'xhc', 'xhe', 'fna', 'fle', 'fhc', 'fhe', 'yld', 'Tray_temp', 'duty', 'Rate_m3', 'Rate_ton', 'sle', 'shc', 'she', 'case'])

# %%
df = pd.read_csv('/content/drive/MyDrive/台塑輕油案子/data/phase2/dataset/train.csv',index_col=0)
df = df.dropna(axis=0).astype('float32')
df.head(3)
# Out:
#         Naphtha Properties_Oxygen_wt%  ...  Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr
# 001-01                            0.0  ...                                              100.0
# 001-02                            0.0  ...                                              100.0
# 001-03                            0.0  ...                                              100.0
#
# [3 rows x 404 columns]

# %%
# X
X = df[c['case']+c['xna']]
print('X.shape',X.shape)

# modelA的Y
Y1 = df[c['sle']+c['shc']+c['she']]
print('Y1.shape',Y1.shape)

duty = df[c['duty']]
density = pd.DataFrame(df[c['Rate_ton']].values/df[c['Rate_m3']].values,
                       columns=['NA_density','LE_density','HC_density','HE_density'],
                       index=df.index)
# modelB的Y
Y2 = duty.join(density)
print('Y2.shape',Y2.shape)

# modelC的Y
Y3 = df[c['Tray_temp']+c['fna']+c['yld']]
print('Y3.shape',Y3.shape)

# (modelA + modelB + modelC)的Y
Y = Y1.join(Y2).join(Y3)
print('Y.shape',Y.shape)
# Out:
# X.shape (16498, 58)
# Y1.shape (16498, 162)
# Y2.shape (16498, 7)
# Y3.shape (16498, 8)
# Y.shape (16498, 177)

# %%
wt = df[c['xle']+c['xhc']+c['xhe']]
df = X.join(Y).join(wt)
x_col = X.columns.tolist()
y_col = Y.columns.tolist()

# %% [markdown]
# # 均值小於0.01的不用列mape

# %%
no_mape_col = df.columns[df.describe().loc['mean']<0.01].tolist()
print(len(no_mape_col))
# Out:
# 143

# %%
normalize_idx_list = []
for i in range(54):
  normalize_idx_list.append([y_col.index(c['sle'][i]),
                             y_col.index(c['shc'][i]),
                             y_col.index(c['she'][i])])
for idx in tqdm(normalize_idx_list):
  assert np.allclose(df[y_col].iloc[:,idx].sum(axis=1),1) # 因為分離係數要確保質量平衡
# Out:
# HBox(children=(FloatProgress(value=0.0, max=54.0), HTML(value='')))

# %%
model = autorch.utils.PartBulider(df,x_col,y_col,normalize_idx_list=normalize_idx_list,device='cuda:0') # 使用 gpu train 快一些
model.loss_fn = nn.SmoothL1Loss() # SmoothL1增加穩健性
model.train()
# Out:
#   0%|          | 1/300 [00:00<04:22,  1.14it/s]
# epoch:0 train_loss:0.0064 valid_loss:0.0018
#  17%|█▋        | 51/300 [00:37<02:56,  1.41it/s]
# epoch:50 train_loss:0.0002 valid_loss:0.0002
#  34%|███▎      | 101/300 [01:14<02:27,  1.35it/s]
# epoch:100 train_loss:0.0001 valid_loss:0.0002
#  50%|█████     | 151/300 [01:51<01:48,  1.37it/s]
# epoch:150 train_loss:0.0001 valid_loss:0.0001
#  67%|██████▋   | 201/300 [02:28<01:12,  1.37it/s]
# epoch:200 train_loss:0.0001 valid_loss:0.0001
#  84%|████████▎ | 251/300 [03:06<00:35,  1.37it/s]
# epoch:250 train_loss:0.0000 valid_loss:0.0000
# 100%|██████████| 300/300 [03:42<00:00,  1.35it/s]
# Sequential(
#   (0): Linear(in_features=58, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=256, out_features=177, bias=True)
#   (5): Sigmoid()
# )

# %%
res = model.test()
res = res.drop(set(res.index)&set(no_mape_col),axis=0)
res['MAPE'].replace([np.nan,np.inf],0,inplace=True)
res
# Out:
#                                                           R2  ...      MAPE
# Individual Component to Light End Split Factor_...         0  ...  0.012294
# Individual Component to Light End Split Factor_...         0  ...  0.012298
# Individual Component to Light End Split Factor_...         0  ...  0.012165
# Individual Component to Light End Split Factor_...   0.99403  ...  0.017416
# Individual Component to Light End Split Factor_...  0.993643  ...  0.043158
# ...                                                      ...  ...       ...
# Yield Summary_Reflux Rate_m3/hr                       0.9917  ...  1.342019
# Yield Summary_Light End Prod. Rate_m3/hr            0.998108  ...  3.297281
# Yield Summary_Heart Cut Prod. Rate_m3/hr            0.997377  ...  0.172566
# Yield Summary_Heavy End Prod. Rate_m3/hr            0.962429  ...  1.930296
# AVG                                                 0.901147  ...  0.000000
#
# [114 rows x 3 columns]

# %% [markdown]
# # 分離係數 to 重量百分比 (sp2wt)

# %%
from autorch.function import sp2wt
x_test = model.data['X_test']
y_pred = model.predict(x_test)
xna = x_test[c['xna']]
xle = sp2wt(xna.values,y_pred[c['sle']].values)
xhc = sp2wt(xna.values,y_pred[c['shc']].values)
xhe = sp2wt(xna.values,y_pred[c['she']].values)
wt_pred = np.hstack((xle,xhc,xhe))
wt_pred = pd.DataFrame(wt_pred,index=x_test.index,columns=c['xle']+c['xhc']+c['xhe'])
wt_pred = wt_pred.round(8)#四捨五入到小數點第8位
wt_pred.head()
# Out:
#         Light End Product Properties_Oxygen_wt%  ...  Heavy End Product Properties_n-Tridecane_wt%
# 054-20                                      0.0  ...                                           0.0
# 288-28                                      0.0  ...                                           0.0
# 410-23                                      0.0  ...                                           0.0
# 239-11                                      0.0  ...                                           0.0
# 267-20                                      0.0  ...                                           0.0
#
# [5 rows x 162 columns]

# %%
wt_real = df.loc[x_test.index,c['xle']+c['xhc']+c['xhe']]
wt_real.head()
# Out:
#         Light End Product Properties_Oxygen_wt%  ...  Heavy End Product Properties_n-Tridecane_wt%
# 054-20                                      0.0  ...                                           0.0
# 288-28                                      0.0  ...                                           0.0
# 410-23                                      0.0  ...                                           0.0
# 239-11                                      0.0  ...                                           0.0
# 267-20                                      0.0  ...                                           0.0
#
# [5 rows x 162 columns]

# %% [markdown]
# # 均值小於0.01的不用列mape

# %%
keep_col = set(wt_pred.columns)-set(no_mape_col)
wt_pred = wt_pred[keep_col]
wt_real = wt_real[keep_col]

# %%
pd.set_option('display.max_rows',200)
res = model.show_metrics(wt_real,wt_pred)
res['MAPE'].replace([np.nan,np.inf],0,inplace=True)# 當分母為'0'則mape會出現inf(若分子也為0得NaN),所以可以忽略NaN和inf
res
# Out:
#                                                           R2  ...          MAPE
# Heavy End Product Properties_1,2-Diethylbenzene...  0.996189  ...      1.573036
# Heart Cut Product Properties_tert-Butylcyclohex...  0.999905  ...      0.340111
# Heavy End Product Properties_2,4-Dimethyloctane...  0.993589  ...      2.446398
# Heart Cut Product Properties_tr2-Hexene_wt%         0.998539  ...      0.000000
# Light End Product Properties_Methylcyclohexane_wt%  0.995857  ...     44.288686
# Heavy End Product Properties_M-Xylene_wt%           0.994617  ...     50.170302
# Light End Product Properties_tr2-Hexene_wt%         0.998962  ...      0.000000
# Heavy End Product Properties_2,2,3,3-Tetramethy...  0.994766  ...      1.501686
# Heart Cut Product Properties_3-Methylpentane_wt%    0.997554  ...      2.229357
# Light End Product Properties_n-Pentane_wt%          0.999251  ...      0.805880
# Heart Cut Product Properties_2-Methylheptane_wt%     0.99987  ...      0.174801
# Heavy End Product Properties_n-Octane_wt%           0.960014  ...  10288.782501
# Heavy End Product Properties_P-Xylene_wt%           0.994345  ...     43.572229
# Heavy End Product Properties_O-Xylene_wt%           0.995057  ...     80.023897
# Heart Cut Product Properties_1-Nonene_wt%           0.998673  ...      0.554579
# Heart Cut Product Properties_t-1,3-Dimethylcycl...   0.99995  ...      0.191701
# Heart Cut Product Properties_2,4-Dimethyloctane...   0.99906  ...      0.556979
# Heart Cut Product Properties_n-Undecane_wt%         0.999801  ...      0.000000
# Heart Cut Product Properties_2,2-Dimethylpentan...  0.999451  ...      0.677969
# Light End Product Properties_Benzene_wt%            0.999044  ...      0.000000
# Heart Cut Product Properties_4-Methyl-1-hexene_wt%  0.999659  ...      0.372861
# Heavy End Product Properties_n-Hexylbenzene_wt%     0.996104  ...      0.000000
# Heart Cut Product Properties_n-Hexane_wt%            0.99825  ...      1.951373
# Heart Cut Product Properties_1-Methyl-2-ethylbe...  0.999681  ...      0.536035
# Heart Cut Product Properties_Methylcyclopentane...   0.99891  ...      1.059676
# Heavy End Product Properties_1-Nonene_wt%           0.990129  ...     18.629152
# Heart Cut Product Properties_2,2,3,3-Tetramethy...  0.998795  ...      0.522880
# Heart Cut Product Properties_Methylcyclohexane_wt%   0.99996  ...      0.159698
# Heart Cut Product Properties_i-Propylbenzene_wt%    0.999628  ...      0.598516
# Light End Product Properties_Propane_wt%            0.998451  ...      0.000000
# Light End Product Properties_Ethylcyclopentane_wt%  0.995107  ...     43.730801
# Light End Product Properties_2-Methylhexane_wt%     0.996909  ...      9.471036
# Heavy End Product Properties_n-Pentylbenzene_wt%    0.996024  ...      1.611277
# Heart Cut Product Properties_i-Pentane_wt%          0.999108  ...      1.824937
# Light End Product Properties_n-Butane_wt%           0.998833  ...      0.000000
# Heart Cut Product Properties_1-trans-3,5-Trimet...  0.999173  ...      0.491301
# Light End Product Properties_tr2-Pentene_wt%        0.998298  ...      0.000000
# Light End Product Properties_t-1,3-Dimethylcycl...  0.998076  ...     15.749419
# Heavy End Product Properties_1-trans-3,5-Trimet...  0.994318  ...     35.068181
# Heavy End Product Properties_1,3,5-Trimethylben...  0.996184  ...      1.515684
# Heart Cut Product Properties_2-Methylhexane_wt%      0.99983  ...      0.239550
# Light End Product Properties_2,2,3-Trimethylbut...  0.995224  ...      2.756846
# Light End Product Properties_2,2-Dimethylpentan...  0.985572  ...      1.650454
# Heavy End Product Properties_tert-Butylcyclohex...  0.997777  ...      1.516118
# Heart Cut Product Properties_n-Octane_wt%           0.999827  ...      0.228928
# Heart Cut Product Properties_Ethylcyclohexane_wt%   0.999628  ...      0.275900
# Heavy End Product Properties_i-Propylbenzene_wt%     0.99312  ...      5.831103
# Light End Product Properties_n-Heptane_wt%          0.993598  ...     31.064257
# Heart Cut Product Properties_Cyclopentane_wt%       0.997902  ...      0.000000
# Heart Cut Product Properties_n-Propylcyclohexan...   0.99896  ...      0.517660
# Heart Cut Product Properties_n-Propylbenzene_wt%    0.999653  ...      0.543719
# Heart Cut Product Properties_Ethylcyclopentane_wt%  0.999959  ...      0.159987
# Light End Product Properties_Cyclohexane_wt%        0.995252  ...      2.252060
# Heart Cut Product Properties_1,2-Diethylbenzene...  0.999877  ...      0.357105
# Heavy End Product Properties_n-Decane_wt%           0.997517  ...      0.000000
# Heart Cut Product Properties_Benzene_wt%            0.999771  ...      0.000000
# Heavy End Product Properties_1,2,3-Trimethylben...  0.997755  ...      1.475286
# Heavy End Product Properties_3-Methylnonane_wt%      0.99374  ...      1.458996
# Light End Product Properties_Cyclopentane_wt%       0.999444  ...      0.000000
# Heart Cut Product Properties_1,2,3-Trimethylben...  0.999845  ...      0.365261
# Heart Cut Product Properties_n-Nonane_wt%           0.999317  ...      0.579156
# Heart Cut Product Properties_M-Xylene_wt%           0.999933  ...      0.405289
# Light End Product Properties_Methylcyclopentane...  0.997206  ...      0.524966
# Heavy End Product Properties_Ethylcyclohexane_wt%   0.992371  ...     21.846151
# Heart Cut Product Properties_n-Decane_wt%           0.999887  ...      0.000000
# Light End Product Properties_n-Hexane_wt%            0.99879  ...      0.794937
# Heart Cut Product Properties_EthylBenzene_wt%       0.999953  ...      0.298061
# Heavy End Product Properties_2-Methyloctane_wt%     0.993774  ...     29.959789
# Heart Cut Product Properties_1,3,5-Trimethylben...  0.999337  ...      0.483703
# Heart Cut Product Properties_n-Heptane_wt%          0.999934  ...      0.161188
# Heart Cut Product Properties_2,2,3-Trimethylbut...  0.999565  ...      0.514010
# Heavy End Product Properties_1-Methyl-2-ethylbe...  0.997186  ...      1.504151
# Heart Cut Product Properties_Cyclohexane_wt%        0.999599  ...      0.662447
# Heart Cut Product Properties_P-Xylene_wt%            0.99994  ...      0.376105
# Heart Cut Product Properties_3-Methylnonane_wt%     0.998715  ...      0.440424
# Heavy End Product Properties_2-Methylheptane_wt%     0.94185  ...      0.000000
# Light End Product Properties_i-Pentane_wt%          0.998685  ...      0.808884
# Heavy End Product Properties_n-Undecane_wt%         0.995414  ...      0.000000
# Light End Product Properties_3-Methylpentane_wt%    0.999076  ...      0.784036
# Heart Cut Product Properties_2,3-Dimethyl-1-hex...  0.999919  ...      0.162976
# Heavy End Product Properties_n-Dodecane_wt%         0.998331  ...      0.000000
# Heart Cut Product Properties_n-Pentylbenzene_wt%    0.999846  ...      0.390583
# Heavy End Product Properties_n-Nonane_wt%           0.995697  ...     12.050574
# Heart Cut Product Properties_n-Pentane_wt%          0.998944  ...      1.881674
# Heavy End Product Properties_n-Propylbenzene_wt%    0.997111  ...      1.529785
# Heavy End Product Properties_n-Propylcyclohexan...   0.99428  ...      1.427023
# Heart Cut Product Properties_O-Xylene_wt%           0.999839  ...      0.569832
# Heart Cut Product Properties_2-Methyloctane_wt%     0.999292  ...      0.516906
# Heart Cut Product Properties_Toluene_wt%            0.999942  ...      0.161679
# Heavy End Product Properties_EthylBenzene_wt%       0.993139  ...     25.917473
# AVG                                                 0.996636  ...      0.000000
#
# [91 rows x 3 columns]
