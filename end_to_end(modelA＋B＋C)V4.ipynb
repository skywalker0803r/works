# %% [markdown]
# <a href="https://colab.research.google.com/github/skywalker0803r/works/blob/master/end_to_end(modelA%EF%BC%8BB%EF%BC%8BC)V4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import joblib
from torch import nn
from tqdm import tqdm_notebook as tqdm
#!pip install autorch
import autorch
import random
import torch

config = {'seed':11}
np.random.seed(config["seed"])
random.seed(config["seed"])
torch.manual_seed(config["seed"])
torch.cuda.manual_seed(config["seed"])

# %%
c = joblib.load('/content/drive/MyDrive/台塑輕油案子/data/phase2/dataset/col_names.pkl')
c.keys()
# Out:
# dict_keys(['xna', 'xle', 'xhc', 'xhe', 'fna', 'fle', 'fhc', 'fhe', 'yld', 'Tray_temp', 'duty', 'Rate_m3', 'Rate_ton', 'sle', 'shc', 'she', 'case'])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/台塑輕油案子/data/phase2/dataset/train.csv',index_col=0)
df = df.dropna(axis=0).astype('float32')
df.head(3)
# Out:
#         Naphtha Properties_Oxygen_wt%  ...  Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr
# 001-01                            0.0  ...                                              100.0
# 001-02                            0.0  ...                                              100.0
# 001-03                            0.0  ...                                              100.0
#
# [3 rows x 404 columns]

# %%
# X
X = df[c['case']+c['xna']]
print('X.shape',X.shape)

# modelA的Y
Y1 = df[c['sle']+c['shc']+c['she']]
print('Y1.shape',Y1.shape)

duty = df[c['duty']]
density = pd.DataFrame(df[c['Rate_ton']].values/df[c['Rate_m3']].values,
                       columns=['NA_density','LE_density','HC_density','HE_density'],
                       index=df.index)
# modelB的Y
Y2 = duty.join(density)
print('Y2.shape',Y2.shape)

# modelC的Y
Y3 = df[c['Tray_temp']+c['fna']+c['yld']]
print('Y3.shape',Y3.shape)

# (modelA + modelB + modelC)的Y
Y = Y1.join(Y2).join(Y3)
print('Y.shape',Y.shape)
# Out:
# X.shape (16498, 58)
# Y1.shape (16498, 162)
# Y2.shape (16498, 7)
# Y3.shape (16498, 8)
# Y.shape (16498, 177)

# %%
wt = df[c['xle']+c['xhc']+c['xhe']]
df = X.join(Y).join(wt)
x_col = X.columns.tolist()
y_col = Y.columns.tolist()

# %%
normalize_idx_list = []
for i in range(54):
  normalize_idx_list.append([y_col.index(c['sle'][i]),
                             y_col.index(c['shc'][i]),
                             y_col.index(c['she'][i])])
for idx in tqdm(normalize_idx_list):
  assert np.allclose(df[y_col].iloc[:,idx].sum(axis=1),1) # 因為分離係數要確保質量平衡
print('pass')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=54.0), HTML(value='')))
# pass

# %%
model = autorch.utils.PartBulider(df,x_col,y_col,normalize_idx_list=normalize_idx_list,device='cuda:0',cut_way=[0.82,0.92]) # 使用 gpu train 快一些
model.loss_fn = nn.SmoothL1Loss() # SmoothL1增加穩健性
model.train()
# Out:
#   0%|          | 1/300 [00:00<03:33,  1.40it/s]
# epoch:0 train_loss:0.0064 valid_loss:0.0017
#  17%|█▋        | 51/300 [00:36<02:58,  1.40it/s]
# epoch:50 train_loss:0.0002 valid_loss:0.0002
#  34%|███▎      | 101/300 [01:12<02:23,  1.39it/s]
# epoch:100 train_loss:0.0001 valid_loss:0.0001
#  50%|█████     | 151/300 [01:48<01:46,  1.39it/s]
# epoch:150 train_loss:0.0001 valid_loss:0.0001
#  67%|██████▋   | 201/300 [02:24<01:10,  1.40it/s]
# epoch:200 train_loss:0.0000 valid_loss:0.0000
#  84%|████████▎ | 251/300 [03:00<00:34,  1.40it/s]
# epoch:250 train_loss:0.0000 valid_loss:0.0000
# 100%|██████████| 300/300 [03:36<00:00,  1.38it/s]

# %% [markdown]
# # predict

# %%
x_test = model.data['X_test']
sp_pred,op_pred = model.predict(x_test).iloc[:,:162],model.predict(x_test).iloc[:,162:] # predict sp op

normalize_idx_list = [ [i,i+54,i+54*2] for i in range(54)]
for idx in tqdm(normalize_idx_list):
  assert np.allclose(sp_pred.iloc[:,idx].sum(axis=1),1) # check massblance
print('pass')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=54.0), HTML(value='')))
# pass

# %% [markdown]
# # sp sesult

# %%
sp_real = model.data['Y_test'].loc[sp_pred.index,sp_pred.columns]
res = model.show_metrics(sp_real,sp_pred,e=0.02)
res
# Out:
#                                                           R2  ...       MAPE
# Individual Component to Light End Split Factor_...         0  ...  0.0170662
# Individual Component to Light End Split Factor_...         0  ...  0.0166185
# Individual Component to Light End Split Factor_...         0  ...   0.017438
# Individual Component to Light End Split Factor_...  0.995549  ...  0.0201259
# Individual Component to Light End Split Factor_...  0.994649  ...  0.0459346
# ...                                                      ...  ...        ...
# Individual Component to Heavy End Split Factor_...  0.995552  ...   0.464374
# Individual Component to Heavy End Split Factor_...  0.998579  ...   0.437909
# Individual Component to Heavy End Split Factor_...  0.996789  ...   0.447391
# Individual Component to Heavy End Split Factor_...         0  ...  0.0169146
# AVG                                                 0.880643  ...    1.62611
#
# [163 rows x 3 columns]

# %% [markdown]
# # op result

# %%
op_real = model.data['Y_test'].loc[op_pred.index,op_pred.columns]
res = model.show_metrics(op_real,op_pred,e=0.02)
res
# Out:
#                                                    R2          MSE       MAPE
# Duty_E062 3.5K Steam Rate_ton/hr             0.993809  0.000134448   0.391192
# Duty_Condenser Heat Duty_Mkcal/hr            0.993439   0.00828352    1.23968
# Duty_Reboiler Heat Duty_Mkcal/hr             0.992392   0.00855476    1.11898
# NA_density                                   0.995988  4.30035e-07   0.067689
# LE_density                                   0.985573   1.8359e-06   0.134852
# HC_density                                   0.995809  5.00887e-07  0.0730977
# HE_density                                   0.991214  1.53809e-06   0.111257
# Column Temp Profile_C011 Tray 15 Temp_oC     0.996017    0.0487234   0.163733
# Column Temp Profile_C013 Tray 16 Temp_oC     0.990526      0.36326   0.239237
# Column Temp Profile_C011 Tray 24 Temp_oC        0.993      0.07283   0.156305
# Naphtha Properties_Naphtha Feed Rate_ton/hr  0.996161     0.122548   0.296639
# Yield Summary_Reflux Rate_m3/hr              0.993049      1.24895    1.23172
# Yield Summary_Light End Prod. Rate_m3/hr     0.996827     0.103821    3.34551
# Yield Summary_Heart Cut Prod. Rate_m3/hr     0.997664    0.0413105   0.163871
# Yield Summary_Heavy End Prod. Rate_m3/hr     0.962186    0.0604073    2.02325
# AVG                                          0.991577     0.138589   0.717135

# %% [markdown]
# # 分離係數 to 重量百分比 (sp2wt)

# %%
def sp2wt(x,s):
  a = 100*x*s
  b = np.diag(x@s.T).reshape(-1,1)
  wt = a/b
  assert np.allclose(np.sum(wt,axis=1),100)
  return wt

# %%
#from autorch.function import sp2wt
x_test = model.data['X_test']
y_pred = model.predict(x_test)
xna = x_test[c['xna']]
xle = sp2wt(xna.values,y_pred[c['sle']].values)
xhc = sp2wt(xna.values,y_pred[c['shc']].values)
xhe = sp2wt(xna.values,y_pred[c['she']].values)
wt_pred = np.hstack((xle,xhc,xhe))
wt_pred = pd.DataFrame(wt_pred,index=x_test.index,columns=c['xle']+c['xhc']+c['xhe'])
wt_pred.head()
# Out:
#         Light End Product Properties_Oxygen_wt%  ...  Heavy End Product Properties_n-Tridecane_wt%
# 316-31                                      0.0  ...                                           0.0
# 283-10                                      0.0  ...                                           0.0
# 128-33                                      0.0  ...                                           0.0
# 289-17                                      0.0  ...                                           0.0
# 087-04                                      0.0  ...                                           0.0
#
# [5 rows x 162 columns]

# %%
wt_real = df.loc[x_test.index,c['xle']+c['xhc']+c['xhe']]
wt_real.head()
# Out:
#         Light End Product Properties_Oxygen_wt%  ...  Heavy End Product Properties_n-Tridecane_wt%
# 316-31                                      0.0  ...                                           0.0
# 283-10                                      0.0  ...                                           0.0
# 128-33                                      0.0  ...                                           0.0
# 289-17                                      0.0  ...                                           0.0
# 087-04                                      0.0  ...                                           0.0
#
# [5 rows x 162 columns]

# %%
for idx in tqdm([c['xle'],c['xhc'],c['xhe']]):
  assert np.allclose(wt_pred.loc[:,idx].sum(axis=1),100) # check massblance
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))

# %%
for idx in tqdm([c['xle'],c['xhc'],c['xhe']]):
  assert np.allclose(wt_real.loc[:,idx].sum(axis=1),100) # check massblance
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))

# %%
pd.set_option('display.max_rows',200)
res = model.show_metrics(wt_real,wt_pred,e=0.02)
res
# Out:
#                                                           R2  ...      MAPE
# Light End Product Properties_Oxygen_wt%                    1  ...       NaN
# Light End Product Properties_Methane_wt%                   1  ...       NaN
# Light End Product Properties_Ethane_wt%                    1  ...       NaN
# Light End Product Properties_Propane_wt%            0.997052  ...  0.511762
# Light End Product Properties_n-Butane_wt%           0.998669  ...  0.512706
# Light End Product Properties_i-Pentane_wt%          0.998239  ...  0.507013
# Light End Product Properties_n-Pentane_wt%          0.998111  ...  0.501317
# Light End Product Properties_tr2-Pentene_wt%        0.998802  ...  0.419714
# Light End Product Properties_Cyclopentane_wt%       0.999525  ...   0.49439
# Light End Product Properties_3-Methylpentane_wt%     0.99921  ...  0.509417
# Light End Product Properties_tr2-Hexene_wt%         0.999641  ...  0.374358
# Light End Product Properties_n-Hexane_wt%           0.999799  ...  0.486024
# Light End Product Properties_Methylcyclopentane...  0.996769  ...  0.482109
# Light End Product Properties_2,2-Dimethylpentan...  0.993131  ...   1.75063
# Light End Product Properties_Benzene_wt%            0.997761  ...   1.02603
# Light End Product Properties_Cyclohexane_wt%        0.996203  ...    2.3502
# Light End Product Properties_2,2,3-Trimethylbut...  0.996278  ...   2.55921
# Light End Product Properties_4-Methyl-1-hexene_wt%  0.996404  ...   1.85697
# Light End Product Properties_2-Methylhexane_wt%     0.997177  ...   6.88529
# Light End Product Properties_t-1,3-Dimethylcycl...  0.997256  ...   7.23638
# Light End Product Properties_n-Heptane_wt%           0.98841  ...   12.9476
# Light End Product Properties_H2O_wt%                       1  ...       NaN
# Light End Product Properties_Methylcyclohexane_wt%  0.982982  ...    12.812
# Light End Product Properties_Ethylcyclopentane_wt%  0.982173  ...   7.71324
# Light End Product Properties_2,3-Dimethyl-1-hex...  0.972036  ...       NaN
# Light End Product Properties_Toluene_wt%            0.974294  ...   11.3535
# Light End Product Properties_2-Methylheptane_wt%    0.967165  ...       NaN
# Light End Product Properties_n-Octane_wt%           0.949374  ...       NaN
# Light End Product Properties_Ethylcyclohexane_wt%   0.971912  ...       NaN
# Light End Product Properties_EthylBenzene_wt%       0.926461  ...       NaN
# Light End Product Properties_P-Xylene_wt%           0.935026  ...       NaN
# Light End Product Properties_M-Xylene_wt%           0.934731  ...       NaN
# Light End Product Properties_O-Xylene_wt%           0.932457  ...       NaN
# Light End Product Properties_2-Methyloctane_wt%     0.867759  ...       NaN
# Light End Product Properties_1-Nonene_wt%           0.856501  ...       NaN
# Light End Product Properties_n-Nonane_wt%           0.858138  ...       NaN
# Light End Product Properties_i-Propylbenzene_wt%    0.934289  ...       NaN
# Light End Product Properties_1-trans-3,5-Trimet...  0.913892  ...       NaN
# Light End Product Properties_n-Propylcyclohexan...  0.915895  ...       NaN
# Light End Product Properties_n-Propylbenzene_wt%    0.951756  ...       NaN
# Light End Product Properties_1,3,5-Trimethylben...  0.968348  ...       NaN
# Light End Product Properties_1-Methyl-2-ethylbe...  0.950207  ...       NaN
# Light End Product Properties_1,2,3-Trimethylben...  0.969272  ...       NaN
# Light End Product Properties_2,4-Dimethyloctane...  0.823911  ...       NaN
# Light End Product Properties_2,2,3,3-Tetramethy...  0.874853  ...       NaN
# Light End Product Properties_3-Methylnonane_wt%     0.857405  ...       NaN
# Light End Product Properties_tert-Butylcyclohex...  0.835357  ...       NaN
# Light End Product Properties_n-Decane_wt%                  0  ...       NaN
# Light End Product Properties_1,2-Diethylbenzene...  0.899007  ...       NaN
# Light End Product Properties_n-Undecane_wt%                0  ...       NaN
# Light End Product Properties_n-Pentylbenzene_wt%           0  ...       NaN
# Light End Product Properties_n-Dodecane_wt%                0  ...       NaN
# Light End Product Properties_n-Hexylbenzene_wt%            0  ...       NaN
# Light End Product Properties_n-Tridecane_wt%               1  ...       NaN
# Heart Cut Product Properties_Oxygen_wt%                    1  ...       NaN
# Heart Cut Product Properties_Methane_wt%                   1  ...       NaN
# Heart Cut Product Properties_Ethane_wt%                    1  ...       NaN
# Heart Cut Product Properties_Propane_wt%            0.998621  ...       NaN
# Heart Cut Product Properties_n-Butane_wt%           0.998689  ...       NaN
# Heart Cut Product Properties_i-Pentane_wt%          0.999019  ...   1.53066
# Heart Cut Product Properties_n-Pentane_wt%          0.998838  ...   1.69523
# Heart Cut Product Properties_tr2-Pentene_wt%        0.999091  ...       NaN
# Heart Cut Product Properties_Cyclopentane_wt%       0.996696  ...    1.6862
# Heart Cut Product Properties_3-Methylpentane_wt%    0.997819  ...   1.81448
# Heart Cut Product Properties_tr2-Hexene_wt%         0.999139  ...  0.850204
# Heart Cut Product Properties_n-Hexane_wt%           0.998099  ...   1.69311
# Heart Cut Product Properties_Methylcyclopentane...  0.999237  ...    1.0095
# Heart Cut Product Properties_2,2-Dimethylpentan...   0.99937  ...  0.687479
# Heart Cut Product Properties_Benzene_wt%            0.999283  ...   1.07503
# Heart Cut Product Properties_Cyclohexane_wt%        0.999581  ...  0.681333
# Heart Cut Product Properties_2,2,3-Trimethylbut...  0.999575  ...  0.503021
# Heart Cut Product Properties_4-Methyl-1-hexene_wt%  0.999754  ...  0.201514
# Heart Cut Product Properties_2-Methylhexane_wt%     0.999877  ...  0.190436
# Heart Cut Product Properties_t-1,3-Dimethylcycl...  0.999962  ...  0.160885
# Heart Cut Product Properties_n-Heptane_wt%          0.999945  ...  0.144733
# Heart Cut Product Properties_H2O_wt%                       1  ...       NaN
# Heart Cut Product Properties_Methylcyclohexane_wt%  0.999967  ...  0.143097
# Heart Cut Product Properties_Ethylcyclopentane_wt%  0.999967  ...  0.142818
# Heart Cut Product Properties_2,3-Dimethyl-1-hex...  0.999938  ...  0.144877
# Heart Cut Product Properties_Toluene_wt%            0.999945  ...  0.143074
# Heart Cut Product Properties_2-Methylheptane_wt%    0.999919  ...  0.150757
# Heart Cut Product Properties_n-Octane_wt%           0.999906  ...  0.182818
# Heart Cut Product Properties_Ethylcyclohexane_wt%   0.999835  ...  0.238199
# Heart Cut Product Properties_EthylBenzene_wt%       0.999953  ...  0.272356
# Heart Cut Product Properties_P-Xylene_wt%           0.999914  ...   0.38204
# Heart Cut Product Properties_M-Xylene_wt%           0.999901  ...  0.408064
# Heart Cut Product Properties_O-Xylene_wt%           0.999829  ...  0.509113
# Heart Cut Product Properties_2-Methyloctane_wt%     0.999387  ...  0.485915
# Heart Cut Product Properties_1-Nonene_wt%           0.998563  ...  0.519758
# Heart Cut Product Properties_n-Nonane_wt%           0.998924  ...  0.499578
# Heart Cut Product Properties_i-Propylbenzene_wt%    0.999341  ...  0.458551
# Heart Cut Product Properties_1-trans-3,5-Trimet...  0.999323  ...  0.446452
# Heart Cut Product Properties_n-Propylcyclohexan...  0.998952  ...  0.356888
# Heart Cut Product Properties_n-Propylbenzene_wt%    0.999426  ...  0.378315
# Heart Cut Product Properties_1,3,5-Trimethylben...   0.99935  ...  0.380658
# Heart Cut Product Properties_1-Methyl-2-ethylbe...  0.999455  ...  0.373884
# Heart Cut Product Properties_1,2,3-Trimethylben...  0.999793  ...  0.331434
# Heart Cut Product Properties_2,4-Dimethyloctane...  0.998899  ...  0.489131
# Heart Cut Product Properties_2,2,3,3-Tetramethy...  0.999396  ...  0.361373
# Heart Cut Product Properties_3-Methylnonane_wt%     0.999283  ...  0.360803
# Heart Cut Product Properties_tert-Butylcyclohex...  0.999948  ...  0.322963
# Heart Cut Product Properties_n-Decane_wt%            0.99986  ...  0.323966
# Heart Cut Product Properties_1,2-Diethylbenzene...   0.99992  ...   0.32873
# Heart Cut Product Properties_n-Undecane_wt%         0.999902  ...  0.347219
# Heart Cut Product Properties_n-Pentylbenzene_wt%    0.999897  ...  0.346686
# Heart Cut Product Properties_n-Dodecane_wt%         0.999934  ...  0.353975
# Heart Cut Product Properties_n-Hexylbenzene_wt%      0.99989  ...  0.645403
# Heart Cut Product Properties_n-Tridecane_wt%               1  ...       NaN
# Heavy End Product Properties_Oxygen_wt%                    1  ...       NaN
# Heavy End Product Properties_Methane_wt%                   1  ...       NaN
# Heavy End Product Properties_Ethane_wt%                    1  ...       NaN
# Heavy End Product Properties_Propane_wt%                   1  ...       NaN
# Heavy End Product Properties_n-Butane_wt%           0.998236  ...       NaN
# Heavy End Product Properties_i-Pentane_wt%          0.997913  ...       NaN
# Heavy End Product Properties_n-Pentane_wt%          0.997237  ...       NaN
# Heavy End Product Properties_tr2-Pentene_wt%        0.997696  ...       NaN
# Heavy End Product Properties_Cyclopentane_wt%       0.993201  ...       NaN
# Heavy End Product Properties_3-Methylpentane_wt%    0.994419  ...       NaN
# Heavy End Product Properties_tr2-Hexene_wt%         0.993534  ...       NaN
# Heavy End Product Properties_n-Hexane_wt%           0.997146  ...       NaN
# Heavy End Product Properties_Methylcyclopentane...  0.999519  ...       NaN
# Heavy End Product Properties_2,2-Dimethylpentan...  0.999531  ...       NaN
# Heavy End Product Properties_Benzene_wt%            0.998571  ...       NaN
# Heavy End Product Properties_Cyclohexane_wt%         0.99976  ...       NaN
# Heavy End Product Properties_2,2,3-Trimethylbut...  0.999669  ...       NaN
# Heavy End Product Properties_4-Methyl-1-hexene_wt%  0.999524  ...       NaN
# Heavy End Product Properties_2-Methylhexane_wt%     0.998491  ...   3.37388
# Heavy End Product Properties_t-1,3-Dimethylcycl...  0.998519  ...   3.33255
# Heavy End Product Properties_n-Heptane_wt%          0.998261  ...   3.49813
# Heavy End Product Properties_H2O_wt%                       1  ...       NaN
# Heavy End Product Properties_Methylcyclohexane_wt%  0.997992  ...   25.7285
# Heavy End Product Properties_Ethylcyclopentane_wt%  0.998313  ...   23.9165
# Heavy End Product Properties_2,3-Dimethyl-1-hex...  0.974818  ...   6.55539
# Heavy End Product Properties_Toluene_wt%            0.994124  ...    40.909
# Heavy End Product Properties_2-Methylheptane_wt%    0.970334  ...   67.8381
# Heavy End Product Properties_n-Octane_wt%           0.982782  ...   62.2959
# Heavy End Product Properties_Ethylcyclohexane_wt%   0.994819  ...   15.2008
# Heavy End Product Properties_EthylBenzene_wt%       0.993093  ...   12.1385
# Heavy End Product Properties_P-Xylene_wt%           0.992934  ...   10.3421
# Heavy End Product Properties_M-Xylene_wt%           0.992972  ...   11.5805
# Heavy End Product Properties_O-Xylene_wt%           0.995302  ...   8.29088
# Heavy End Product Properties_2-Methyloctane_wt%     0.994373  ...   6.71551
# Heavy End Product Properties_1-Nonene_wt%           0.985565  ...   2.94561
# Heavy End Product Properties_n-Nonane_wt%           0.989269  ...   2.72987
# Heavy End Product Properties_i-Propylbenzene_wt%    0.982063  ...   1.92192
# Heavy End Product Properties_1-trans-3,5-Trimet...  0.995639  ...   6.30823
# Heavy End Product Properties_n-Propylcyclohexan...  0.994012  ...   1.44945
# Heavy End Product Properties_n-Propylbenzene_wt%    0.993189  ...   1.32705
# Heavy End Product Properties_1,3,5-Trimethylben...  0.995156  ...   1.86887
# Heavy End Product Properties_1-Methyl-2-ethylbe...  0.993044  ...   1.57241
# Heavy End Product Properties_1,2,3-Trimethylben...  0.996556  ...   1.43367
# Heavy End Product Properties_2,4-Dimethyloctane...  0.991998  ...   1.87955
# Heavy End Product Properties_2,2,3,3-Tetramethy...  0.994074  ...   1.71213
# Heavy End Product Properties_3-Methylnonane_wt%     0.993338  ...   1.43786
# Heavy End Product Properties_tert-Butylcyclohex...  0.995697  ...   1.45749
# Heavy End Product Properties_n-Decane_wt%           0.997115  ...   1.46246
# Heavy End Product Properties_1,2-Diethylbenzene...  0.997511  ...   1.48434
# Heavy End Product Properties_n-Undecane_wt%         0.996787  ...   1.51087
# Heavy End Product Properties_n-Pentylbenzene_wt%    0.997292  ...   1.51391
# Heavy End Product Properties_n-Dodecane_wt%         0.997923  ...   1.69926
# Heavy End Product Properties_n-Hexylbenzene_wt%     0.997238  ...   1.56455
# Heavy End Product Properties_n-Tridecane_wt%               1  ...       NaN
# AVG                                                 0.954638  ...   4.32711
#
# [163 rows x 3 columns]

# %%
model.to('cpu')

# %%
model.shrink() #節省空間

# %%
# 保存
joblib.dump(model,'/content/drive/MyDrive/台塑輕油案子/model/end_to_end(modelA＋B＋C).pkl')
# Out:
# ['/content/drive/MyDrive/台塑輕油案子/model/end_to_end(modelA＋B＋C).pkl']
