# %% [markdown]
# <a href="https://colab.research.google.com/github/skywalker0803r/works/blob/master/%E6%A8%A1%E7%B5%84%E5%8C%96%E9%9B%86%E6%88%90%E5%AD%B8%E7%BF%92.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # get_oof

# %%
from sklearn.model_selection import KFold
def get_oof(model ,x_train, y_train, x_test):
    kf = KFold(n_splits=5,random_state=0)
    oof_train = np.zeros((len(x_train),))
    oof_test = np.zeros((len(x_test),))
    oof_test_skf = np.empty((5, len(x_test)))

    for i, (train_index, test_index) in enumerate(kf.split(x_train)):
        x_tr = x_train.loc[train_index]
        y_tr = y_train.loc[train_index]
        x_te = x_train.loc[test_index]

        model.fit(x_tr.values, y_tr.values)

        oof_train[test_index] = model.predict(x_te)
        oof_test_skf[i, :] = model.predict(x_test)

    oof_test[:] = oof_test_skf.mean(axis=0)
    return oof_train.reshape(-1, 1), oof_test.reshape(-1, 1)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.model_selection import RandomizedSearchCV
import numpy as np
import warnings 
warnings.simplefilter('ignore')

def 集成學習(X_train,y_train,X_test,tuning_meta_model=False,meta_model_params=None): 
  
  # def base model
  base_models = [
      RandomForestRegressor(random_state=0),
      LinearRegression(),
      KNeighborsRegressor(),
      SVR()]
  
  # def meta model
  meta_model = XGBRegressor(objective="reg:squarederror",random_state=0)
  
  # get all base model's oof_train and oof_test
  all_oof_train = np.empty((len(X_train),0))
  all_oof_test = np.empty((len(X_test),0))
  for model in base_models:
    oof_train,oof_test = get_oof(model,X_train,y_train,X_test)
    all_oof_train = np.hstack((all_oof_train,oof_train))
    all_oof_test = np.hstack((all_oof_test,oof_test))

  # train and tunning meta model
  if tuning_meta_model == True:
    cv = RandomizedSearchCV(estimator = meta_model,
                            param_distributions = meta_model_params,
                            n_jobs = -1,
                            n_iter = 20,
                            cv = 3)
    cv.fit(all_oof_train,y_train)
    meta_model = cv.best_estimator_
  
  # not tunning meta model
  if tuning_meta_model == False:
    meta_model.fit(all_oof_train,y_train)
  
  # return meta model predict
  return meta_model.predict(all_oof_test)

# %% [markdown]
# # 評估

# %%
from sklearn.metrics import r2_score
import numpy as np

def rmse(y_true, y_pred):
    return np.sqrt(((y_pred - y_true) ** 2).mean())

def mape(y_true, y_pred,dropinf=False):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    ape = np.abs((y_true - y_pred) / y_true)
    if dropinf == True:
      ape = ape[np.isfinite(ape)]
    return np.mean(ape) * 100

def metric(y_true,y_pred,y_name):
  R2 = r2_score(y_true,y_pred)
  RMSE = rmse(y_true,y_pred)
  MAPE = mape(y_true,y_pred)
  return pd.DataFrame({'R2':R2,'RMSE':RMSE,'MAPE':MAPE},index=[y_name])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # trainset

# %%
import pandas as pd
train = pd.read_csv('/content/drive/My Drive/台塑輕油案子/輕油實驗數據(保留大部份欄位,三個基本規則清洗過).csv')
X = train[['T10','T50','T90','N+A in Feed']].rename(columns={'N+A in Feed':'NA'})
y = train.iloc[:,17:-1]
train = X.join(y)
train.head()
# Out:
#      T10    T50    T90      NA   C5NP  ...    C9A  C10NP  C10IP   C10N   C10A
# 0  100.5  119.2  146.5  31.978  0.272  ...  3.661  0.875  5.257  0.525  0.319
# 1   99.6  117.9  145.5  31.568  0.297  ...  2.995  0.881  5.591  1.119  0.303
# 2  100.0  118.8  145.6  31.344  0.262  ...  2.979  0.865  5.641  0.964  0.289
# 3  100.4  118.6  142.9  31.453  0.224  ...  2.964  0.830  5.637  0.968  0.281
# 4  100.4  118.1  142.2  32.190  0.243  ...  3.725  0.835  4.823  0.969  0.290
#
# [5 rows x 27 columns]

# %% [markdown]
# # testset

# %%
test = pd.read_csv('/content/drive/My Drive/台塑輕油案子/test_without_outlier.csv')
X_test = test[['T10','T50','T90','N+A']].rename(columns={'N+A':'NA'})
y_test = test.iloc[:,4:]
y_test.columns = y.columns
test = X_test.join(y_test)
test.head()
# Out:
#      T10    T50    T90      NA   C5NP  ...    C9A  C10NP  C10IP   C10N   C10A
# 0   98.6  119.2  146.1  40.133  1.142  ...  3.481  1.088  5.652  0.618  0.597
# 1  105.4  122.2  148.2  32.175  0.122  ...  3.963  1.069  6.025  0.585  0.484
# 2  105.8  122.7  149.2  31.428  0.098  ...  3.997  1.034  6.107  0.543  0.456
# 3  105.4  122.4  147.6  31.390  0.122  ...  3.982  1.013  6.054  0.545  0.449
# 4  105.4  122.6  148.2  32.418  0.072  ...  4.227  0.930  5.828  0.519  0.463
#
# [5 rows x 27 columns]

# %% [markdown]
# # 特徵工程

# %%
def 特徵工程(df):
  df['T90-T50'] = df['T90'] - df['T50']
  df['T50-T10'] = df['T50'] - df['T10']
  return df

# %%
X = 特徵工程(X)
train = X.join(y)
print(train.shape)
train.head()
# Out:
# (4521, 29)
#      T10    T50    T90      NA  T90-T50  ...    C9A  C10NP  C10IP   C10N   C10A
# 0  100.5  119.2  146.5  31.978     27.3  ...  3.661  0.875  5.257  0.525  0.319
# 1   99.6  117.9  145.5  31.568     27.6  ...  2.995  0.881  5.591  1.119  0.303
# 2  100.0  118.8  145.6  31.344     26.8  ...  2.979  0.865  5.641  0.964  0.289
# 3  100.4  118.6  142.9  31.453     24.3  ...  2.964  0.830  5.637  0.968  0.281
# 4  100.4  118.1  142.2  32.190     24.1  ...  3.725  0.835  4.823  0.969  0.290
#
# [5 rows x 29 columns]

# %%
X_test = 特徵工程(X_test)
test = X_test.join(y_test)
print(test.shape)
test.head()
# Out:
# (170, 29)
#      T10    T50    T90      NA  T90-T50  ...    C9A  C10NP  C10IP   C10N   C10A
# 0   98.6  119.2  146.1  40.133     26.9  ...  3.481  1.088  5.652  0.618  0.597
# 1  105.4  122.2  148.2  32.175     26.0  ...  3.963  1.069  6.025  0.585  0.484
# 2  105.8  122.7  149.2  31.428     26.5  ...  3.997  1.034  6.107  0.543  0.456
# 3  105.4  122.4  147.6  31.390     25.2  ...  3.982  1.013  6.054  0.545  0.449
# 4  105.4  122.6  148.2  32.418     25.6  ...  4.227  0.930  5.828  0.519  0.463
#
# [5 rows x 29 columns]

# %% [markdown]
# # 專業分群

# %%
from xgboost import XGBClassifier
cut_num = 5
#訓練資料均溫
train['AVG_T'] = train[['T10','T50','T90']].mean(axis=1)
#測試資料均溫
test['AVG_T'] = test[['T10','T50','T90']].mean(axis=1)
#訓練資料依據均溫切群
train['群代碼'] = pd.qcut(train['AVG_T'],cut_num,labels = [ i for i in range(cut_num)]).astype('int')
#利用4000筆資料訓練一個分群器
xgb_c = XGBClassifier().fit(train[['AVG_T']].sample(4000,random_state=0),train['群代碼'].sample(4000,random_state=0))
print('預測準度:',xgb_c.score(train[['AVG_T']],train['群代碼']))
#利用分群器對測試資料產生群代碼
test['群代碼'] = xgb_c.predict(test[['AVG_T']])
# Out:
# 預測準度: 1.0

# %% [markdown]
# # 檢查資料(應有特徵工程項和群落標籤)

# %%
train.head()
# Out:
#      T10    T50    T90      NA  T90-T50  ...  C10IP   C10N   C10A       AVG_T  群代碼
# 0  100.5  119.2  146.5  31.978     27.3  ...  5.257  0.525  0.319  122.066667    3
# 1   99.6  117.9  145.5  31.568     27.6  ...  5.591  1.119  0.303  121.000000    2
# 2  100.0  118.8  145.6  31.344     26.8  ...  5.641  0.964  0.289  121.466667    2
# 3  100.4  118.6  142.9  31.453     24.3  ...  5.637  0.968  0.281  120.633333    2
# 4  100.4  118.1  142.2  32.190     24.1  ...  4.823  0.969  0.290  120.233333    2
#
# [5 rows x 31 columns]

# %%
test.head()
# Out:
#      T10    T50    T90      NA  T90-T50  ...  C10IP   C10N   C10A       AVG_T  群代碼
# 0   98.6  119.2  146.1  40.133     26.9  ...  5.652  0.618  0.597  121.300000    2
# 1  105.4  122.2  148.2  32.175     26.0  ...  6.025  0.585  0.484  125.266667    4
# 2  105.8  122.7  149.2  31.428     26.5  ...  6.107  0.543  0.456  125.900000    4
# 3  105.4  122.4  147.6  31.390     25.2  ...  6.054  0.545  0.449  125.133333    4
# 4  105.4  122.6  148.2  32.418     25.6  ...  5.828  0.519  0.463  125.400000    4
#
# [5 rows x 31 columns]

# %% [markdown]
# # 觀察各群落成份分布

# %%
import seaborn as sns
import matplotlib.pyplot as plt
table = pd.DataFrame(index=['group_'+str(群代碼) for 群代碼 in range(cut_num)],columns=y.columns)

#根據不同群和y_name找出其均值
for y_name in y.columns:
  for 群代碼 in range(cut_num):
    均值 = round(train[train['群代碼']==群代碼][y_name].mean(),2)
    table.loc[['group_'+str(群代碼)],[y_name]] = 均值

#繪圖
plt.figure(figsize=(23,cut_num))
sns.heatmap(table.astype(float)[::-1],annot=True,linewidths=0.1,cmap='YlGnBu')

# %% [markdown]
# # Def x_col,y_col

# %%
x_columns = X.columns.tolist()
y_columns = y.columns.tolist()
print(x_columns)
print(y_columns)
# Out:
# ['T10', 'T50', 'T90', 'NA', 'T90-T50', 'T50-T10']
# ['C5NP', 'C5IP', 'C5N', 'C6NP', 'C6IP', 'C6N', 'C6A', 'C7NP', 'C7IP', 'C7N', 'C7A', 'C8NP', 'C8IP', 'C8N', 'C8A', 'C9NP', 'C9IP', 'C9N', 'C9A', 'C10NP', 'C10IP', 'C10N', 'C10A']

# %% [markdown]
# # features scaler

# %%
def data_scaler(my_data,my_scaler):
  new_data = my_scaler.transform(my_data)
  return pd.DataFrame(new_data ,index=my_data.index ,columns=my_data.columns)

# %%
def inv_data_scaler(my_data,my_scaler):
  new_data = my_scaler.inverse_transform(my_data)
  return pd.DataFrame(new_data ,index=my_data.index ,columns=my_data.columns)

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(train[x_columns])
X_scaler
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
train[x_columns] = data_scaler(train[x_columns],X_scaler)
print(train.shape)
train.head()
# Out:
# (4521, 31)
#         T10       T50       T90        NA  ...   C10N   C10A       AVG_T  群代碼
# 0  0.435162  0.540969  0.471798 -1.028321  ...  0.525  0.319  122.066667    3
# 1  0.353320  0.340075  0.237602 -1.077598  ...  1.119  0.303  121.000000    2
# 2  0.389694  0.479156  0.261022 -1.104520  ...  0.964  0.289  121.466667    2
# 3  0.426068  0.448249 -0.371307 -1.091419  ...  0.968  0.281  120.633333    2
# 4  0.426068  0.370982 -0.535244 -1.002841  ...  0.969  0.290  120.233333    2
#
# [5 rows x 31 columns]

# %%
test[x_columns] = data_scaler(test[x_columns],X_scaler)
print(test.shape)
test.head()
# Out:
# (170, 31)
#         T10       T50       T90        NA  ...   C10N   C10A       AVG_T  群代碼
# 0  0.262385  0.540969  0.378120 -0.048196  ...  0.618  0.597  121.300000    2
# 1  0.880744  1.004573  0.869931 -1.004644  ...  0.585  0.484  125.266667    4
# 2  0.917118  1.081840  1.104127 -1.094424  ...  0.543  0.456  125.900000    4
# 3  0.880744  1.035480  0.729414 -1.098991  ...  0.545  0.449  125.133333    4
# 4  0.880744  1.066386  0.869931 -0.975439  ...  0.519  0.463  125.400000    4
#
# [5 rows x 31 columns]

# %% [markdown]
# # 查看分數

# %%
def get_score(y_pred,y_test):
  res = pd.DataFrame()
  for y_name in y_test.columns:
    res = res.append(metric(y_test[y_name],y_pred[y_name],y_name))
  res.loc['AVG'] = res.mean()
  return res

# %% [markdown]
# # 單純建模表現

# %%
def 單純建模結果():
  #預測值表格
  y_pred = pd.DataFrame(index = y_test.index ,columns = y_test.columns)
  #填表格
  for y_name in y_columns:
    y_pred.loc[:,y_name] = XGBRegressor(objective="reg:squarederror").fit(train[x_columns],train[y_name]).predict(test[x_columns])
  #分數
  return get_score(y_pred,y_test)
res_1 = 單純建模結果()
res_1
# Out:
#              R2      RMSE       MAPE
# C5NP   0.895524  0.276226  45.656649
# C5IP   0.761398  0.249962  61.328125
# C5N    0.926344  0.037153  40.327227
# C6NP   0.087657  0.386438   7.135374
# C6IP   0.869269  0.377932  10.094344
# C6N    0.866756  0.604498   6.090150
# C6A   -0.500739  0.209298  29.959152
# C7NP   0.976621  0.336270   3.568161
# C7IP   0.835262  0.448499   5.709674
# C7N    0.980121  0.587567   3.718948
# C7A    0.342649  0.376779   6.405377
# C8NP   0.979171  0.249427   2.882047
# C8IP   0.944762  0.366958   3.484247
# C8N    0.883078  0.623989   6.220210
# C8A    0.503311  0.572877   5.804315
# C9NP   0.983918  0.202730   3.489706
# C9IP   0.952504  0.344669   3.307700
# C9N    0.656951  0.472975   7.442244
# C9A    0.624569  0.371284   9.200705
# C10NP  0.350941  0.170325  13.790475
# C10IP  0.856097  0.387583   6.975425
# C10N   0.588030  0.083807  10.054178
# C10A   0.424785  0.176778  21.884071
# AVG    0.686477  0.344088  13.675152

# %% [markdown]
# #集成學習表現

# %%
from tqdm import tqdm

def 單純集成學習結果():
  #預測值表格
  y_pred = pd.DataFrame(index = y_test.index ,columns = y_test.columns)

  #填表
  for y_name in tqdm(y_columns):
    y_pred.loc[:,y_name] = 集成學習(train[x_columns],train[y_name],test[x_columns])

  #分數
  return get_score(y_pred,y_test)
res_2 = 單純集成學習結果()
res_2
# Out:
# 100%|██████████| 23/23 [01:40<00:00,  4.30s/it]
#              R2      RMSE       MAPE
# C5NP   0.887127  0.287111  42.581378
# C5IP   0.722249  0.269690  62.895353
# C5N    0.946817  0.031570  43.849538
# C6NP   0.145409  0.374008   6.494623
# C6IP   0.875377  0.368998  10.369125
# C6N    0.898458  0.527709   6.026184
# C6A   -0.204851  0.187534  32.492513
# C7NP   0.982737  0.288964   3.246853
# C7IP   0.815570  0.474548   5.602716
# C7N    0.967455  0.751804   4.239998
# C7A    0.645942  0.276520   5.471896
# C8NP   0.979648  0.246555   2.872846
# C8IP   0.945061  0.365962   3.309621
# C8N    0.912515  0.539754   5.557260
# C8A    0.120959  0.762121   8.240109
# C9NP   0.989805  0.161414   2.867205
# C9IP   0.954631  0.336862   3.194050
# C9N    0.498194  0.572043  10.046839
# C9A    0.623565  0.371780   9.462485
# C10NP  0.367362  0.168156  13.453518
# C10IP  0.874676  0.361698   6.470877
# C10N   0.507512  0.091632   9.809846
# C10A   0.406125  0.179622  20.403493
# AVG    0.689667  0.347654  13.867753

# %% [markdown]
# # 集成學習加調參表現

# %%
def 集成學習加調參結果():
  #參數池_1
  params_1 = {
    'learning_rate': np.arange(0.01 ,0.2 ,0.01),
    'max_depth': np.arange(3 ,10 ,1),
    'subsample': np.arange(0.5 ,1.0 ,0.1),
    'colsample_bytree': np.arange(0.5 ,1.0 ,0.1),
    'gamma': np.arange(0 ,1.0 ,0.1)
  }
  #表格
  y_pred = pd.DataFrame(index = y_test.index ,columns = y_test.columns)
  #填表
  for y_name in tqdm(y_columns):
    y_pred.loc[:,y_name] = 集成學習(X,y[y_name],X_test,tuning_meta_model=True,meta_model_params=params_1)
  #分數
  return get_score(y_pred,y_test)
res_3 = 集成學習加調參結果()
res_3
# Out:
# 100%|██████████| 23/23 [06:40<00:00, 17.49s/it]
#              R2      RMSE       MAPE
# C5NP   0.884633  0.290265  41.859919
# C5IP   0.728710  0.266535  58.817027
# C5N    0.884057  0.046614  99.296203
# C6NP   0.119115  0.379718   6.972299
# C6IP   0.882400  0.358449  10.986903
# C6N    0.882128  0.568560   6.494183
# C6A    0.183911  0.154341  26.318402
# C7NP   0.978728  0.320764   3.851141
# C7IP   0.856198  0.419031   5.396996
# C7N    0.965642  0.772463   4.660158
# C7A    0.636847  0.280049   5.367725
# C8NP   0.979231  0.249071   2.883207
# C8IP   0.941994  0.376040   3.396556
# C8N    0.920971  0.513006   5.271398
# C8A    0.325538  0.667572   7.300472
# C9NP   0.983069  0.208016   3.861525
# C9IP   0.925340  0.432135   4.021874
# C9N    0.544492  0.545015   9.011970
# C9A    0.491520  0.432094  11.127379
# C10NP  0.305497  0.176186  14.154105
# C10IP  0.831040  0.419973   7.395813
# C10N   0.647330  0.077541   8.775369
# C10A   0.389370  0.182138  20.170167
# AVG    0.708163  0.353721  15.973513

# %% [markdown]
# # 專業分群加集成學習結果

# %%
def 專業分群加集成學習結果():
  #預測值空白表格
  y_pred = pd.DataFrame(index = y_test.index ,columns = y_test.columns)

  #開始填表(加入分群概念)
  for 群代碼 in sorted(test.群代碼.unique()):
    群落_train = train.loc[train['群代碼'] == 群代碼 , :]
    群落_test  = test.loc[test['群代碼'] == 群代碼 , :]
    for y_name in tqdm(y_columns):
      y_pred.loc[群落_test.index,y_name] = 集成學習(群落_train[x_columns].reset_index(drop=True),
                                                   群落_train[y_name].reset_index(drop=True),
                                                   群落_test[x_columns].reset_index(drop=True))

  #分數
  return get_score(y_pred,y_test)
res_4 = 專業分群加集成學習結果()
res_4
# Out:
# 100%|██████████| 23/23 [00:11<00:00,  2.03it/s]
# 100%|██████████| 23/23 [00:10<00:00,  2.12it/s]
# 100%|██████████| 23/23 [00:10<00:00,  2.17it/s]
# 100%|██████████| 23/23 [00:09<00:00,  2.32it/s]
# 100%|██████████| 23/23 [00:09<00:00,  2.31it/s]
#              R2      RMSE       MAPE
# C5NP   0.891654  0.281294  32.472575
# C5IP   0.754699  0.253446  45.564254
# C5N    0.931186  0.035912  44.167136
# C6NP  -0.085143  0.421449   7.667197
# C6IP   0.893642  0.340887   9.743852
# C6N    0.896857  0.531852   6.568592
# C6A   -0.945388  0.238296  27.710161
# C7NP   0.977160  0.332372   3.448045
# C7IP   0.865503  0.405248   5.340126
# C7N    0.957680  0.857298   4.440073
# C7A   -0.793346  0.622330   7.821847
# C8NP   0.977543  0.258992   2.916513
# C8IP   0.910865  0.466144   3.967352
# C8N    0.904294  0.564545   5.467070
# C8A   -1.051015  1.164137   8.684315
# C9NP   0.987253  0.180495   3.337502
# C9IP   0.923714  0.436816   4.059437
# C9N    0.548740  0.542468   7.533240
# C9A    0.614233  0.376360   8.904108
# C10NP  0.132032  0.196964  16.294844
# C10IP  0.832389  0.418293   7.561907
# C10N  -1.879242  0.221558  13.821385
# C10A   0.252822  0.201476  23.726629
# AVG    0.412962  0.406462  13.096442

# %% [markdown]
# # 序列預測加集成學習加專業分群

# %%
def 序列預測_集成學習_專業分群():
  #預測值空白表格
  y_pred = pd.DataFrame(index = y_test.index ,columns = y_test.columns)

  #專業分群
  for 群代碼 in sorted(test.群代碼.unique()):
    #該群落data
    群落_train = train.loc[train['群代碼'] == 群代碼 , :]
    群落_test  = test.loc[test['群代碼'] == 群代碼 , :]
    #該群落的X_train,X_test
    群落_X_train = 群落_train[x_columns]
    群落_X_test = 群落_test[x_columns]
    #開始依序預測23個y
    for y_name in tqdm(y_columns):
      群落_y_train = 群落_train[y_name]
      #利用集成學習在 [該群落,該y_name]上填上預測值
      y_pred.loc[群落_X_test.index,y_name] = 集成學習(群落_X_train.reset_index(drop=True),
                                                 群落_y_train.reset_index(drop=True),
                                                 群落_X_test.reset_index(drop=True))
      #加入該輪y_train給下一輪做訓練
      群落_X_train = 群落_X_train.join(群落_y_train)
      #將該輪y_pred加入下一輪做預測
      群落_X_test = 群落_X_test.join(y_pred.loc[群落_X_test.index,y_name])

  #分數
  return get_score(y_pred,y_test)
res_5 = 序列預測_集成學習_專業分群()
res_5
# Out:
# 100%|██████████| 23/23 [00:16<00:00,  1.14it/s]
# 100%|██████████| 23/23 [00:16<00:00,  1.08it/s]
# 100%|██████████| 23/23 [00:16<00:00,  1.09it/s]
# 100%|██████████| 23/23 [00:16<00:00,  1.04it/s]
# 100%|██████████| 23/23 [00:16<00:00,  1.08it/s]
#              R2      RMSE       MAPE
# C5NP   0.891654  0.281294  32.472575
# C5IP   0.739714  0.261073  46.344304
# C5N    0.735463  0.070411  31.346115
# C6NP  -0.196852  0.442610   8.025553
# C6IP   0.850644  0.403957  10.423882
# C6N    0.872429  0.591490   7.064280
# C6A    0.129088  0.159441  21.071798
# C7NP   0.972978  0.361522   3.765951
# C7IP   0.834635  0.449351   5.714448
# C7N    0.971613  0.702133   4.527242
# C7A    0.608422  0.290802   5.757733
# C8NP   0.974394  0.276554   3.315185
# C8IP   0.933992  0.401137   3.865746
# C8N    0.881837  0.627294   6.592467
# C8A    0.358531  0.651039   7.092624
# C9NP   0.985616  0.191728   3.294325
# C9IP   0.929563  0.419736   3.784852
# C9N    0.633295  0.489011   7.616320
# C9A    0.636027  0.365574   8.804148
# C10NP  0.071736  0.203691  16.246485
# C10IP  0.812284  0.442670   7.966917
# C10N  -0.077366  0.135528  17.163735
# C10A  -0.533038  0.288595  38.948272
# AVG    0.609420  0.369854  13.095868

# %% [markdown]
# # 序列預測加集成學習加專業分群加調參

# %%
def 序列預測_集成學習_專業分群_調參():
  
  #參數池_1
  params_1 = {
    'learning_rate': np.arange(0.01 ,0.2 ,0.01),
    'max_depth': np.arange(3 ,10 ,1),
    'subsample': np.arange(0.5 ,1.0 ,0.1),
    'colsample_bytree': np.arange(0.5 ,1.0 ,0.1),
    'gamma': np.arange(0 ,1.0 ,0.1)
  }
  
  #待填空白表格
  y_pred = pd.DataFrame(index = y_test.index ,columns = y_test.columns)

  #對群做遍歷
  for 群代碼 in sorted(test.群代碼.unique()):
    #撈出該群落data
    群落_train = train.loc[train['群代碼'] == 群代碼 , :]
    群落_test  = test.loc[test['群代碼'] == 群代碼 , :]
    #撈出該群落的X_train,X_test
    群落_X_train = 群落_train[x_columns]
    群落_X_test = 群落_test[x_columns]
    #利用該群落資料,開始依序預測23個y
    for y_name in tqdm(y_columns):
      群落_y_train = 群落_train[y_name]
      #利用調參版本的集成學習在 [該群落,該y_name]上填上預測值
      y_pred.loc[群落_X_test.index,y_name] = 集成學習(群落_X_train.reset_index(drop=True),
                                                 群落_y_train.reset_index(drop=True),
                                                 群落_X_test.reset_index(drop=True),
                                                 tuning_meta_model=True,
                                                 meta_model_params=params_1)
      #加入該輪y_train給下一輪做訓練
      群落_X_train = 群落_X_train.join(群落_y_train)
                   '集成學習&調參':res_3.RMSE,
                   '專業分群&集成學習':res_4.RMSE,
                   '集成學習&專業分群&序列預測':res_5.RMSE,
                   '集成學習&專業分群&序列預測&調參':res_6.RMSE})
print('紅色代表RMSE最低')
df.style.apply(lambda x: ["background: red" if v == np.min(x) else "" for v in x], axis = 1)
# Out:
# 紅色代表RMSE最低
# <style  type="text/css" >
#     #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row0_col0 {
#             background:  red;
#         }    #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row1_col5 {
#             background:  red;
#         }    #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row2_col1 {
#             background:  red;
#         }    #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row3_col1 {
#             background:  red;
#         }    #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row4_col5 {
#             background:  red;
#         }    #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row5_col1 {
#             background:  red;
#         }    #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row6_col5 {
#             background:  red;
#         }    #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row7_col1 {
#             background:  red;
#         }    #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row8_col3 {
#             background:  red;
#         }    #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row9_col0 {
#             background:  red;
#         }    #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row10_col1 {
#             background:  red;
#         }    #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row11_col1 {
#             background:  red;
#         }    #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row12_col1 {
#             background:  red;
#         }    #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row13_col2 {
#             background:  red;
#         }    #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row14_col0 {
#             background:  red;
#         }    #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row15_col1 {
#             background:  red;
#         }    #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row16_col1 {
#             background:  red;
#         }    #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row17_col5 {
#             background:  red;
#         }    #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row18_col4 {
#             background:  red;
#         }    #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row19_col1 {
#             background:  red;
#         }    #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row20_col1 {
#             background:  red;
#         }    #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row21_col2 {
#             background:  red;
#         }    #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row22_col0 {
#             background:  red;
#         }    #T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row23_col0 {
#             background:  red;
#         }</style><table id="T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >單純xboost</th>        <th class="col_heading level0 col1" >單純集成學習</th>        <th class="col_heading level0 col2" >集成學習&調參</th>        <th class="col_heading level0 col3" >專業分群&集成學習</th>        <th class="col_heading level0 col4" >集成學習&專業分群&序列預測</th>        <th class="col_heading level0 col5" >集成學習&專業分群&序列預測&調參</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T
#                         <td id="T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row3_col1" class="data row3 col1" >0.374008</td>
#                         <td id="T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row3_col2" class="data row3 col2" >0.379718</td>
#                         <td id="T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row3_col3" class="data row3 col3" >0.421449</td>
#                         <td id="T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row3_col4" class="data row3 col4" >0.44261</td>
#                         <td id="T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row3_col5" class="data row3 col5" >0.440434</td>
#             </tr>
#             <tr>
#                         <th id="T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002level0_row4" class="row_heading level0 row4" >C6IP</th>
#                         <td id="T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row4_col0" class="data row4 col0" >0.377932</td>
#                         <td id="T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row4_col1" class="data row4 col1" >0.368998</td>
#                         <td id="T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row4_col2" class="data row4 col2" >0.358449</td>
#                         <td id="T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row4_col3" class="data row4 col3" >0.340887</td>
#                         <td id="T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row4_col4" class="data row4 col4" >0.403957</td>
#                         <td id="T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row4_col5" class="data row4 col5" >0.298335</td>
#             </tr>
#             <tr>
#                         <th id="T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002level0_row5" class="row_heading level0 row5" >C6N</th>
#                         <td id="T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row5_col0" class="data row5 col0" >0.604498</td>
#                         <td id="T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row5_col1" class="data row5 col1" >0.527709</td>
#                         <td id="T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row5_col2" class="data row5 col2" >0.56856</td>
#                         <td id="T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row5_col3" class="data row5 col3" >0.531852</td>
#                         <td id="T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row5_col4" class="data row5 col4" >0.59149</td>
#                         <td id="T_da80fbd6_e4d9_11e9_bcc3_0242ac1c0002row5_col5" class="d

# %% [markdown]
# # 保存res

# %%
#res_1.to_excel('/content/drive/My Drive/台塑輕油案子/預測方法結果/簡單xgboost.xlsx')
#res_2.to_excel('/content/drive/My Drive/台塑輕油案子/預測方法結果/單純集成學習.xlsx')
#res_3.to_excel('/content/drive/My Drive/台塑輕油案子/預測方法結果/集成學習&調參.xlsx')
#res_4.to_excel('/content/drive/My Drive/台塑輕油案子/預測方法結果/專業分群&集成學習.xlsx')
#res_5.to_excel('/content/drive/My Drive/台塑輕油案子/預測方法結果/集成學習&專業分群&序列預測.xlsx')
#res_6.to_excel('/content/drive/My Drive/台塑輕油案子/預測方法結果/集成學習&專業分群&序列預測&調參.xlsx')
#print('save done!')
